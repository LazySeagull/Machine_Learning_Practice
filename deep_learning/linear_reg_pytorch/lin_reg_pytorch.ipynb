# %%
#the torch init

import torch

# %%
#libraries

import numpy 
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing

# %%
#linear reg using tensors and autograd
#it apparently worked here maybe cuz i updated wsl
housing = fetch_california_housing()

# %%
housing.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
housing.target_names
# Out:
# ['MedHouseVal']

# %%
x_train_full , x_test , y_train_full , y_test = train_test_split(housing.data , housing.target ,
                                                                 test_size=0.15,random_state=42)

# %%
type(x_train_full)
# Out:
# numpy.ndarray

# %%
y_train_full.shape
# Out:
# (17544,)

# %%
y_train_full.shape
# Out:
# (17544,)

# %%
x_train , x_valid , y_train , y_valid = train_test_split(x_train_full , y_train_full ,
                                                         test_size=0.15 ,random_state=42)

# %%
x_valid.shape
# Out:
# (2632, 8)

# %%
x_train = torch.FloatTensor(x_train)                #float tensor auto converts array into 32 bit float 
                                                    #dont need 64 bit float to preserve memory 
x_valid = torch.FloatTensor(x_valid)
x_test = torch.FloatTensor(x_test)
means = x_train.mean(dim=0 , keepdims=True)
stds = x_train.std(dim=0 , keepdims=True)
x_train = (x_train - means)/stds                    #standard scaler z score aka standard scaler
x_valid = (x_valid - means)/stds
x_test = (x_test - means)/stds

# %%
y_train = torch.FloatTensor(y_train).reshape(-1 , 1) 
y_valid = torch.FloatTensor(y_valid).reshape(-1 , 1)
y_test = torch.FloatTensor(y_test).reshape(-1 , 1)

# %%
torch.manual_seed(42)  #just like rng = numpy.random.default_rng
n_features = x_train.shape[1]
w = torch.rand((n_features , 1) , requires_grad=True) #random initial weights column matrix 
b = torch.tensor(0. , requires_grad=True) #bias

# %%
#linear reg

learning_rate = 0.4
n_epoch = 20

for epoch in range(n_epoch):
    y_pred = x_train @ w + b
    loss = ((y_pred - y_train) **2).mean()
    loss.backward()
    
    with torch.no_grad():
        b -= learning_rate * b.grad
        w -= learning_rate * w.grad 
        b.grad.zero_()
        w.grad.zero_()
    
    print(f"Epoch  : {epoch + 1}/{n_epoch} , loss: {loss.item()}")
# Out:
# Epoch  : 1/20 , loss: 7.675676345825195
# Epoch  : 2/20 , loss: 1.369813084602356
# Epoch  : 3/20 , loss: 0.8449282050132751
# Epoch  : 4/20 , loss: 0.7360148429870605
# Epoch  : 5/20 , loss: 0.6953126788139343
# Epoch  : 6/20 , loss: 0.6725728511810303
# Epoch  : 7/20 , loss: 0.6559969782829285
# Epoch  : 8/20 , loss: 0.6422801613807678
# Epoch  : 9/20 , loss: 0.6303563714027405
# Epoch  : 10/20 , loss: 0.6198002099990845
# Epoch  : 11/20 , loss: 0.6103882193565369
# Epoch  : 12/20 , loss: 0.6019703149795532
# Epoch  : 13/20 , loss: 0.594429075717926
# Epoch  : 14/20 , loss: 0.5876659750938416
# Epoch  : 15/20 , loss: 0.5815954804420471
# Epoch  : 16/20 , loss: 0.5761424899101257
# Epoch  : 17/20 , loss: 0.5712404251098633
# Epoch  : 18/20 , loss: 0.5668303370475769
# Epoch  : 19/20 , loss: 0.5628600716590881
# Epoch  : 20/20 , loss: 0.5592830181121826
