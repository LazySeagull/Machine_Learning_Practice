# %%
import torch

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import torchvision
import torchvision.transforms.v2 as T
from torch.utils.data import DataLoader , TensorDataset
import torch.nn as nn
import torchmetrics
import torch.nn.functional as F

# %%
import optuna

# %%
toTensor = T.Compose([T.ToImage() , T.ToDtype(torch.float32 , scale=True)])

train_and_valid_data = torchvision.datasets.FashionMNIST(
    root="datasets" , train=True , download=True , transform=toTensor
)

test_data = torchvision.datasets.FashionMNIST(
    root="datasets" , train=False , download=True , transform=toTensor
)

torch.manual_seed(42)
train_data , valid_data = torch.utils.data.random_split(
    train_and_valid_data , [55_000 , 5_000]
)

# %%
train_loader = DataLoader(train_data , shuffle=True , batch_size = 512 , pin_memory=True , num_workers=4 , prefetch_factor=2)
valid_loader = DataLoader(valid_data , shuffle=True , batch_size = 512 , pin_memory=True , num_workers=4 , prefetch_factor=2)
test_loader = DataLoader(test_data , shuffle=True , batch_size = 512 , pin_memory=True , num_workers=4 , prefetch_factor=2)

# %%
x_sample , y_sample = train_data[0]

# %%
y_sample
# Out:
# 9

# %%
x_sample.shape
# Out:
# torch.Size([1, 28, 28])

# %%
x_sample.dtype
# Out:
# torch.float32

# %%
train_and_valid_data.classes[y_sample]
# Out:
# 'Ankle boot'

# %%
for i in range(1 , 10):
    print(train_and_valid_data.classes[i] , end=" ")
# Out:
# Trouser Pullover Dress Coat Sandal Shirt Sneaker Bag Ankle boot

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda

# %%
n_epoch = 20

# %%
def eval(model , metric , val_loader):
    model.eval()
    metric.reset()
    
    with torch.no_grad():
        for x_batch , y_batch in val_loader:
            x_batch , y_batch = x_batch.to(device) , y_batch.to(device)
            
            y_pred = model(x_batch)
            
            metric.update(y_pred , y_batch)
            
    return metric.compute()





def train_eval(model , train_loader , criterion , optimizer ,
               val_loader , metric , n_epoch ):
    
    history = {"train_loss" : [] , "train_metric(accuracy)" : [] , "val_metric(accuracy)" : []}

    for epoch in range(n_epoch):
        model.train()
        metric.reset()
        total_loss = 0
        for x_batch , y_batch in train_loader:
            #data
            x_batch , y_batch = x_batch.to(device) , y_batch.to(device)
            
            #forward
            
            y_pred  = model(x_batch)
            
            #loss 
            
            loss = criterion(y_pred , y_batch)
            total_loss += loss.item()
            
            #optimizer
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            metric.update(y_pred , y_batch)
            
        loss_mean = total_loss/len(train_loader)
        
        history["train_loss"].append(loss_mean)
        history["train_metric(accuracy)"].append(metric.compute().item())
        
        history["val_metric(accuracy)"].append(eval(model , metric , val_loader).item())
        
        print(f"Epoch : {epoch + 1}/{n_epoch}, "
              f"Train Loss : {history['train_loss'][-1]}, "
              f"Train Metric ( Accuracy) : {history['train_metric(accuracy)'][-1]}, "
              f"Val Metric (accuracy) : {history['val_metric(accuracy)'][-1]}")
        
        
    return history

# %%
class ImageClassifier(nn.Module):
    def __init__(self , n_inputs , n_hidden1 , n_hidden2 , n_classes):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.Flatten(),
            nn.Linear(n_inputs , n_hidden1) , 
            nn.ReLU(),
            nn.Linear(n_hidden1 , n_hidden2),
            nn.ReLU(),
            nn.Linear(n_hidden2 , n_classes)
        )
        
        
    def forward(self , x):
        return self.mlp(x)
    
torch.manual_seed(42)
model = ImageClassifier(n_inputs= 28 * 28 , n_hidden1=  300 , 
                        n_hidden2= 100 , n_classes= 10).to(device)

learning_rate = 0.1

sentropy = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters() , lr=learning_rate , momentum=0 )

accuracy_metric = torchmetrics.Accuracy(task='multiclass' , num_classes=10).to(device)

train_eval(model=model , 
           train_loader=train_loader,
           criterion=sentropy,
           optimizer=optimizer,
           val_loader=valid_loader,
           metric=accuracy_metric,
           n_epoch=n_epoch)
# Out:
# Epoch : 1/20, Train Loss : 1.406682523312392, Train Metric ( Accuracy) : 0.5595818161964417, Val Metric (accuracy) : 0.6424000263214111
# Epoch : 2/20, Train Loss : 0.7617398550113043, Train Metric ( Accuracy) : 0.7130545377731323, Val Metric (accuracy) : 0.7508000135421753
# Epoch : 3/20, Train Loss : 0.6311827169524299, Train Metric ( Accuracy) : 0.7703090906143188, Val Metric (accuracy) : 0.7767999768257141
# Epoch : 4/20, Train Loss : 0.5653285764985614, Train Metric ( Accuracy) : 0.7989272475242615, Val Metric (accuracy) : 0.8082000017166138
# Epoch : 5/20, Train Loss : 0.5227762217874881, Train Metric ( Accuracy) : 0.8143091201782227, Val Metric (accuracy) : 0.8184000253677368
# Epoch : 6/20, Train Loss : 0.49167994023473177, Train Metric ( Accuracy) : 0.826090931892395, Val Metric (accuracy) : 0.8270000219345093
# Epoch : 7/20, Train Loss : 0.4737724717016573, Train Metric ( Accuracy) : 0.8313272595405579, Val Metric (accuracy) : 0.8277999758720398
# Epoch : 8/20, Train Loss : 0.4532129082966734, Train Metric ( Accuracy) : 0.8374000191688538, Val Metric (accuracy) : 0.7997999787330627
# Epoch : 9/20, Train Loss : 0.44459800560165336, Train Metric ( Accuracy) : 0.8415818214416504, Val Metric (accuracy) : 0.8438000082969666
# Epoch : 10/20, Train Loss : 0.4270699413286315, Train Metric ( Accuracy) : 0.8477818369865417, Val Metric (accuracy) : 0.8432000279426575
# Epoch : 11/20, Train Loss : 0.4194272715184424, Train Metric ( Accuracy) : 0.8501636385917664, Val Metric (accuracy) : 0.8366000056266785
# Epoch : 12/20, Train Loss : 0.40726327813333935, Train Metric ( Accuracy) : 0.8552545309066772, Val Metric (accuracy) : 0.8378000259399414
# Epoch : 13/20, Train Loss : 0.39879963602180835, Train Metric ( Accuracy) : 0.8569090962409973, Val Metric (accuracy) : 0.8497999906539917
# Epoch : 14/20, Train Loss : 0.38835844590708063, Train Metric ( Accuracy) : 0.8600000143051147, Val Metric (accuracy) : 0.8447999954223633
# Epoch : 15/20, Train Loss : 0.3825460487493762, Train Metric ( Accuracy) : 0.8631272912025452, Val Metric (accuracy) : 0.8367999792098999
# Epoch : 16/20, Train Loss : 0.3748966411308006, Train Metric ( Accuracy) : 0.8653818368911743, Val Metric (accuracy) : 0.8537999987602234
# Epoch : 17/20, Train Loss : 0.368025004863739, Train Metric ( Accuracy) : 0.8683090806007385, Val Metric (accuracy) : 0.849399983882904
# Epoch : 18/20, Train Loss : 0.36134419645424243, Train Metric ( Accuracy) : 0.8696363568305969, Val Metric (accuracy) : 0.8479999899864197
# Epoch : 19/20, Train Loss : 0.35778535847310666, Train Metric ( Accuracy) : 0.8715999722480774, Val Metric (accuracy) : 0.8600000143051147
# Epoch : 20/20, Train Loss : 0.35009388128916424, Train Metric ( Accuracy) : 0.8737272620201111, Val Metric (accuracy) : 0.8622000217437744

# %%
model.eval()

x_new , y_new = next(iter(valid_loader))

print(len(valid_loader))
print(x_new.shape)
x_new = x_new[:3].to(device)
print(x_new.shape)
# Out:
# 10
# torch.Size([512, 1, 28, 28])
# torch.Size([3, 1, 28, 28])

# %%
with torch.no_grad():
    y_pred_logits = model(x_new)
    
    
    
print(y_pred_logits)

y_pred = y_pred_logits.argmax(dim=1)

print(y_pred)
# Out:
# tensor([[-1.5756, -2.8279, -2.6576, -2.2836, -3.9924,  2.8587, -3.0943,  8.4436,
#           1.9728,  5.3338],
#         [ 3.2444, -5.2624,  2.7566, -2.0151,  2.3112, -0.4453,  3.1874, -3.2803,
#           9.8131, -6.7189],
#         [ 4.5906, -1.1313,  0.8625,  1.3348, -1.0837, -1.0367,  4.4671, -3.7178,
#          -0.4634, -2.7325]], device='cuda:0')
# tensor([7, 8, 0], device='cuda:0')

# %%
y_proba = F.softmax(y_pred_logits , dim=1)
y_proba.round(decimals = 3)
# Out:
# tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0040, 0.0000, 0.9520, 0.0010,
#          0.0420],
#         [0.0010, 0.0000, 0.0010, 0.0000, 0.0010, 0.0000, 0.0010, 0.0000, 0.9960,
#          0.0000],
#         [0.5090, 0.0020, 0.0120, 0.0200, 0.0020, 0.0020, 0.4500, 0.0000, 0.0030,
#          0.0000]], device='cuda:0')

# %%
# getting the top four logits and proba

y_top4_logits , y_top4_indices = torch.topk(y_pred_logits , k=4 , dim=1)
y_top4_proba = F.softmax(y_top4_logits , dim=1)
y_top4_proba.round(decimals = 3)
# Out:
# tensor([[0.9520, 0.0420, 0.0040, 0.0010],
#         [0.9960, 0.0010, 0.0010, 0.0010],
#         [0.5140, 0.4540, 0.0200, 0.0120]], device='cuda:0')

# %%
y_top4_indices
# Out:
# tensor([[7, 9, 5, 8],
#         [8, 0, 6, 2],
#         [0, 6, 3, 2]], device='cuda:0')

# %%
#fine tuning the model using optuna

# %%
def objective(trial):
    learning_rate = trial.suggest_float("learning_rate" , 1e-5 , 1e-1 , log=True)
    n_hidden = trial.suggest_int("n_hidden" , 20 , 300)
    model = ImageClassifier(n_inputs= 1 * 28 * 28 , n_hidden1= n_hidden , n_hidden2=n_hidden,
                            n_classes=10 ).to(device)
    
    optimizer = torch.optim.SGD(model.parameters() , momentum=0 , lr = learning_rate)
    
    
    xentropy = nn.CrossEntropyLoss()
    
    accuracy_metric = torchmetrics.Accuracy(task = "multiclass" , num_classes=10).to(device)
    
    best_val_score = 0.0
    
    for epoch in range(n_epoch):
        history = train_eval(model , train_loader , xentropy , optimizer , 
                             valid_loader , accuracy_metric , n_epoch)
        
        val_score = max(history['val_metric(accuracy)'])
        
        if val_score > best_val_score:
            best_val_score = val_score
            
        trial.report(val_score , epoch)
        
        if trial.should_prune():
            raise optuna.TrialPruned()
        
    
    return best_val_score

# %%
torch.manual_seed(42)
sampler = optuna.samplers.TPESampler(seed = 42)
study = optuna.create_study(direction="maximize" , sampler=sampler)
study.optimize(objective , n_trials=5)
# Out:
# [I 2026-01-27 17:32:17,350] A new study created in memory with name: no-name-c0f0b504-fae6-4be3-944f-039b27dab279
# Epoch : 1/20, Train Loss : 2.306647128529019, Train Metric ( Accuracy) : 0.09843636304140091, Val Metric (accuracy) : 0.10360000282526016
# Epoch : 2/20, Train Loss : 2.3025815111619456, Train Metric ( Accuracy) : 0.1111818179488182, Val Metric (accuracy) : 0.11620000004768372
# Epoch : 3/20, Train Loss : 2.2984959483146667, Train Metric ( Accuracy) : 0.12303636223077774, Val Metric (accuracy) : 0.12540000677108765
# Epoch : 4/20, Train Loss : 2.2944650186432733, Train Metric ( Accuracy) : 0.13207273185253143, Val Metric (accuracy) : 0.13519999384880066
# Epoch : 5/20, Train Loss : 2.2904361574738115, Train Metric ( Accuracy) : 0.13752727210521698, Val Metric (accuracy) : 0.1404000073671341
# Epoch : 6/20, Train Loss : 2.28646292730614, Train Metric ( Accuracy) : 0.1422181874513626, Val Metric (accuracy) : 0.14319999516010284
# Epoch : 7/20, Train Loss : 2.2825059162245855, Train Metric ( Accuracy) : 0.14616364240646362, Val Metric (accuracy) : 0.14339999854564667
# Epoch : 8/20, Train Loss : 2.2785526469901756, Train Metric ( Accuracy) : 0.14874544739723206, Val Metric (accuracy) : 0.14560000598430634
# Epoch : 9/20, Train Loss : 2.274609139672032, Train Metric ( Accuracy) : 0.15149091184139252, Val Metric (accuracy) : 0.14740000665187836
# Epoch : 10/20, Train Loss : 2.270699437017794, Train Metric ( Accuracy) : 0.15405455231666565, Val Metric (accuracy) : 0.1518000066280365
# Epoch : 11/20, Train Loss : 2.2667784801235906, Train Metric ( Accuracy) : 0.1573818176984787, Val Metric (accuracy) : 0.15760000050067902
# Epoch : 12/20, Train Loss : 2.262867179181841, Train Metric ( Accuracy) : 0.16099999845027924, Val Metric (accuracy) : 0.16040000319480896
# Epoch : 13/20, Train Loss : 2.2589645518196955, Train Metric ( Accuracy) : 0.16645453870296478, Val Metric (accuracy) : 0.16599999368190765
# Epoch : 14/20, Train Loss : 2.2549506580388106, Train Metric ( Accuracy) : 0.1727636307477951, Val Metric (accuracy) : 0.17219999432563782
# Epoch : 15/20, Train Loss : 2.2509638512576067, Train Metric ( Accuracy) : 0.17974545061588287, Val Metric (accuracy) : 0.17739999294281006
# Epoch : 16/20, Train Loss : 2.246908892084051, Train Metric ( Accuracy) : 0.18716363608837128, Val Metric (accuracy) : 0.18639999628067017
# Epoch : 17/20, Train Loss : 2.242811776973583, Train Metric ( Accuracy) : 0.19538182020187378, Val Metric (accuracy) : 0.1956000030040741
# Epoch : 18/20, Train Loss : 2.2386416307202093, Train Metric ( Accuracy) : 0.2046181857585907, Val Metric (accuracy) : 0.2029999941587448
# Epoch : 19/20, Train Loss : 2.2343779846473977, Train Metric ( Accuracy) : 0.21490909159183502, Val Metric (accuracy) : 0.2117999941110611
# Epoch : 20/20, Train Loss : 2.2301127778159247, Train Metric ( Accuracy) : 0.22569091618061066, Val Metric (accuracy) : 0.22280000150203705
# Epoch : 1/20, Train Loss : 2.225688272052341, Train Metric ( Accuracy) : 0.23716363310813904, Val Metric (accuracy) : 0.23639999330043793
# Epoch : 2/20, Train Loss : 2.2212710226023638, Train Metric ( Accuracy) : 0.2494909018278122, Val Metric (accuracy) : 0.25119999051094055
# Epoch : 3/20, Train Loss : 2.2168385496845953, Train Metric ( Accuracy) : 0.26181817054748535, Val Metric (accuracy) : 0.2667999863624573
# Epoch : 4/20, Train Loss : 2.212215571491807, Train Metric ( Accuracy) : 0.2741272747516632, Val Metric (accuracy) : 0.28060001134872437
# Epoch : 5/20, Train Loss : 2.2074938085344105, Train Metric ( Accuracy) : 0.28619998693466187, Val Metric (accuracy) : 0.29159998893737793
# Epoch : 6/20, Train Loss : 2.2026935992417513, Train Metric ( Accuracy) : 0.2985272705554962, Val Metric (accuracy) : 0.30059999227523804
# Epoch : 7/20, Train Loss : 2.19769940773646, Train Metric ( Accuracy) : 0.3094181716442108, Val Metric (accuracy) : 0.31200000643730164
# Epoch : 8/20, Train Loss : 2.19256360884066, Train Metric ( Accuracy) : 0.31970909237861633, Val Metric (accuracy) : 0.32100000977516174
# Epoch : 9/20, Train Loss : 2.187423571392342, Train Metric ( Accuracy) : 0.3296363651752472, Val Metric (accuracy) : 0.33219999074935913
# Epoch : 10/20, Train Loss : 2.1820350377647966, Train Metric ( Accuracy) : 0.3389090895652771, Val Metric (accuracy) : 0.3409999907016754
# Epoch : 11/20, Train Loss : 2.176589992311266, Train Metric ( Accuracy) : 0.34774544835090637, Val Metric (accuracy) : 0.3458000123500824
# Epoch : 12/20, Train Loss : 2.1709108463040105, Train Metric ( Accuracy) : 0.35472726821899414, Val Metric (accuracy) : 0.35120001435279846
# Epoch : 13/20, Train Loss : 2.1651314585297197, Train Metric ( Accuracy) : 0.3627272844314575, Val Metric (accuracy) : 0.35839998722076416
# Epoch : 14/20, Train Loss : 2.1593203213479786, Train Metric ( Accuracy) : 0.3696908950805664, Val Metric (accuracy) : 0.36579999327659607
# Epoch : 15/20, Train Loss : 2.1531864824118436, Train Metric ( Accuracy) : 0.3768181800842285, Val Metric (accuracy) : 0.3707999885082245
# Epoch : 16/20, Train Loss : 2.1470182251047203, Train Metric ( Accuracy) : 0.3843636214733124, Val Metric (accuracy) : 0.37560001015663147
# Epoch : 17/20, Train Loss : 2.1404713789621987, Train Metric ( Accuracy) : 0.39047273993492126, Val Metric (accuracy) : 0.3824000060558319
# Epoch : 18/20, Train Loss : 2.1340374924518444, Train Metric ( Accuracy) : 0.39739999175071716, Val Metric (accuracy) : 0.38760000467300415
# Epoch : 19/20, Train Loss : 2.12734536992179, Train Metric ( Accuracy) : 0.40350908041000366, Val Metric (accuracy) : 0.39500001072883606
# Epoch : 20/20, Train Loss : 2.120313052777891, Train Metric ( Accuracy) : 0.41021817922592163, Val Metric (accuracy) : 0.4020000100135803
# Epoch : 1/20, Train Loss : 2.1133471881901778, Train Metric ( Accuracy) : 0.4166909158229828, Val Metric (accuracy) : 0.40860000252723694
# Epoch : 2/20, Train Loss : 2.106006450123257, Train Metric ( Accuracy) : 0.42343637347221375, Val Metric (accuracy) : 0.4146000146865845
# Epoch : 3/20, Train Loss : 2.0984782686939947, Train Metric ( Accuracy) : 0.4294181764125824, Val Metric (accuracy) : 0.4221999943256378
# Epoch : 4/20, Train Loss : 2.0908590665570013, Train Metric ( Accuracy) : 0.4360909163951874, Val Metric (accuracy) : 0.42719998955726624
# Epoch : 5/20, Train Loss : 2.0830213162634106, Train Metric ( Accuracy) : 0.4416363537311554, Val Metric (accuracy) : 0.43459999561309814
# Epoch : 6/20, Train Loss : 2.0750091318730957, Train Metric ( Accuracy) : 0.4469272792339325, Val Metric (accuracy) : 0.44339999556541443
# Epoch : 7/20, Train Loss : 2.0667559107144675, Train Metric ( Accuracy) : 0.4535999894142151, Val Metric (accuracy) : 0.45080000162124634
# Epoch : 8/20, Train Loss : 2.0581763364650585, Train Metric ( Accuracy) : 0.46036362648010254, Val Metric (accuracy) : 0.4560000002384186
# Epoch : 9/20, Train Loss : 2.0495171127495944, Train Metric ( Accuracy) : 0.4665272831916809, Val Metric (accuracy) : 0.4643999934196472
# Epoch : 10/20, Train Loss : 2.040668233677193, Train Metric ( Accuracy) : 0.4726727306842804, Val Metric (accuracy) : 0.46939998865127563
# Epoch : 11/20, Train Loss : 2.031462181497503, Train Metric ( Accuracy) : 0.47940000891685486, Val Metric (accuracy) : 0.4772000014781952
# Epoch : 12/20, Train Loss : 2.02204821507136, Train Metric ( Accuracy) : 0.4851999878883362, Val Metric (accuracy) : 0.48500001430511475
# Epoch : 13/20, Train Loss : 2.0124455403398582, Train Metric ( Accuracy) : 0.49301818013191223, Val Metric (accuracy) : 0.4918000102043152
# Epoch : 14/20, Train Loss : 2.0026775532298617, Train Metric ( Accuracy) : 0.49883636832237244, Val Metric (accuracy) : 0.49959999322891235
# Epoch : 15/20, Train Loss : 1.9925312201182048, Train Metric ( Accuracy) : 0.5060363411903381, Val Metric (accuracy) : 0.5059999823570251
# Epoch : 16/20, Train Loss : 1.9822856960473236, Train Metric ( Accuracy) : 0.5127454400062561, Val Metric (accuracy) : 0.5144000053405762
# Epoch : 17/20, Train Loss : 1.971750944852829, Train Metric ( Accuracy) : 0.5192545652389526, Val Metric (accuracy) : 0.5185999870300293
# Epoch : 18/20, Train Loss : 1.9608926397782784, Train Metric ( Accuracy) : 0.5253636240959167, Val Metric (accuracy) : 0.5260000228881836
# Epoch : 19/20, Train Loss : 1.9499893022908106, Train Metric ( Accuracy) : 0.5314000248908997, Val Metric (accuracy) : 0.5332000255584717
# Epoch : 20/20, Train Loss : 1.9386446155883648, Train Metric ( Accuracy) : 0.5374363660812378, Val Metric (accuracy) : 0.5386000275611877
# Epoch : 1/20, Train Loss : 1.9271493388546839, Train Metric ( Accuracy) : 0.5425999760627747, Val Metric (accuracy) : 0.5461999773979187
# Epoch : 2/20, Train Loss : 1.9156211062713906, Train Metric ( Accuracy) : 0.548872709274292, Val Metric (accuracy) : 0.550599992275238
# Epoch : 3/20, Train Loss : 1.9037460773079484, Train Metric ( Accuracy) : 0.5527999997138977, Val Metric (accuracy) : 0.5564000010490417
# Epoch : 4/20, Train Loss : 1.89162411292394, Train Metric ( Accuracy) : 0.5589454770088196, Val Metric (accuracy) : 0.5605999827384949
# Epoch : 5/20, Train Loss : 1.879322545395957, Train Metric ( Accuracy) : 0.5626363754272461, Val Metric (accuracy) : 0.5637999773025513
# Epoch : 6/20, Train Loss : 1.8669227085731648, Train Metric ( Accuracy) : 0.5663999915122986, Val Metric (accuracy) : 0.569599986076355
# Epoch : 7/20, Train Loss : 1.854390291152177, Train Metric ( Accuracy) : 0.5707818269729614, Val Metric (accuracy) : 0.5734000205993652
# Epoch : 8/20, Train Loss : 1.841596202717887, Train Metric ( Accuracy) : 0.5753818154335022, Val Metric (accuracy) : 0.5776000022888184
# Epoch : 9/20, Train Loss : 1.8287094798352983, Train Metric ( Accuracy) : 0.5784000158309937, Val Metric (accuracy) : 0.5809999704360962
# Epoch : 10/20, Train Loss : 1.8156161838107638, Train Metric ( Accuracy) : 0.5813272595405579, Val Metric (accuracy) : 0.5866000056266785
# Epoch : 11/20, Train Loss : 1.8026130640948261, Train Metric ( Accuracy) : 0.5849272608757019, Val Metric (accuracy) : 0.5884000062942505
# Epoch : 12/20, Train Loss : 1.7890210306202923, Train Metric ( Accuracy) : 0.587218165397644, Val Metric (accuracy) : 0.5893999934196472
# Epoch : 13/20, Train Loss : 1.775906409378405, Train Metric ( Accuracy) : 0.5897636413574219, Val Metric (accuracy) : 0.5910000205039978
# Epoch : 14/20, Train Loss : 1.7623277593542028, Train Metric ( Accuracy) : 0.5931817889213562, Val Metric (accuracy) : 0.5942000150680542
# Epoch : 15/20, Train Loss : 1.7489869561460283, Train Metric ( Accuracy) : 0.5960000157356262, Val Metric (accuracy) : 0.5965999960899353
# Epoch : 16/20, Train Loss : 1.735534703290021, Train Metric ( Accuracy) : 0.5981272459030151, Val Metric (accuracy) : 0.6003999710083008
# Epoch : 17/20, Train Loss : 1.7219060449688524, Train Metric ( Accuracy) : 0.600563645362854, Val Metric (accuracy) : 0.6001999974250793
# Epoch : 18/20, Train Loss : 1.7083116228933688, Train Metric ( Accuracy) : 0.602472722530365, Val Metric (accuracy) : 0.600600004196167
# Epoch : 19/20, Train Loss : 1.6946602905238117, Train Metric ( Accuracy) : 0.6046181917190552, Val Metric (accuracy) : 0.603600025177002
# Epoch : 20/20, Train Loss : 1.681444479359521, Train Metric ( Accuracy) : 0.6070181727409363, Val Metric (accuracy) : 0.6046000123023987
# Epoch : 1/20, Train Loss : 1.667897657111839, Train Metric ( Accuracy) : 0.6096363663673401, Val Metric (accuracy) : 0.6074000000953674
# Epoch : 2/20, Train Loss : 1.6548052286660229, Train Metric ( Accuracy) : 0.6115818023681641, Val Metric (accuracy) : 0.609000027179718
# Epoch : 3/20, Train Loss : 1.6410935609428972, Train Metric ( Accuracy) : 0.6133272647857666, Val Metric (accuracy) : 0.6104000210762024
# Epoch : 4/20, Train Loss : 1.628020433364091, Train Metric ( Accuracy) : 0.6153454780578613, Val Metric (accuracy) : 0.6129999756813049
# Epoch : 5/20, Train Loss : 1.6148476159131084, Train Metric ( Accuracy) : 0.6168000102043152, Val Metric (accuracy) : 0.6154000163078308
# Epoch : 6/20, Train Loss : 1.6021127369668748, Train Metric ( Accuracy) : 0.618327260017395, Val Metric (accuracy) : 0.6150000095367432
# Epoch : 7/20, Train Loss : 1.5892780952983432, Train Metric ( Accuracy) : 0.620090901851654, Val Metric (accuracy) : 0.6161999702453613
# Epoch : 8/20, Train Loss : 1.576399196077276, Train Metric ( Accuracy) : 0.6219272613525391, Val Metric (accuracy) : 0.6179999709129333
# Epoch : 9/20, Train Loss : 1.563759563145814, Train Metric ( Accuracy) : 0.623236358165741, Val Metric (accuracy) : 0.6191999912261963
# Epoch : 10/20, Train Loss : 1.5514286966235549, Train Metric ( Accuracy) : 0.6239272952079773, Val Metric (accuracy) : 0.6209999918937683
# Epoch : 11/20, Train Loss : 1.5391157258439947, Train Metric ( Accuracy) : 0.6250908970832825, Val Metric (accuracy) : 0.6209999918937683
# Epoch : 12/20, Train Loss : 1.5268533395396338, Train Metric ( Accuracy) : 0.6253636479377747, Val Metric (accuracy) : 0.6215999722480774
# Epoch : 13/20, Train Loss : 1.5148527578071311, Train Metric ( Accuracy) : 0.6257091164588928, Val Metric (accuracy) : 0.6218000054359436
# Epoch : 14/20, Train Loss : 1.5031906763712566, Train Metric ( Accuracy) : 0.6266909241676331, Val Metric (accuracy) : 0.6226000189781189
# Epoch : 15/20, Train Loss : 1.4916506321341902, Train Metric ( Accuracy) : 0.6271636486053467, Val Metric (accuracy) : 0.623199999332428
# Epoch : 16/20, Train Loss : 1.4802297022607591, Train Metric ( Accuracy) : 0.6279454827308655, Val Metric (accuracy) : 0.6223999857902527
# Epoch : 17/20, Train Loss : 1.4689058407589242, Train Metric ( Accuracy) : 0.6282908916473389, Val Metric (accuracy) : 0.6233999729156494
# Epoch : 18/20, Train Loss : 1.4581757971534022, Train Metric ( Accuracy) : 0.628600001335144, Val Metric (accuracy) : 0.6245999932289124
# Epoch : 19/20, Train Loss : 1.4473577660542947, Train Metric ( Accuracy) : 0.6290727257728577, Val Metric (accuracy) : 0.6245999932289124
# Epoch : 20/20, Train Loss : 1.4365067106706124, Train Metric ( Accuracy) : 0.6293091177940369, Val Metric (accuracy) : 0.6245999932289124
# Epoch : 1/20, Train Loss : 1.4258603784773085, Train Metric ( Accuracy) : 0.6299636363983154, Val Metric (accuracy) : 0.6255999803543091
# Epoch : 2/20, Train Loss : 1.4155260964676186, Train Metric ( Accuracy) : 0.6298909187316895, Val Metric (accuracy) : 0.6258000135421753
# Epoch : 3/20, Train Loss : 1.4050878628536507, Train Metric ( Accuracy) : 0.6302363872528076, Val Metric (accuracy) : 0.6262000203132629
# Epoch : 4/20, Train Loss : 1.3951397979701008, Train Metric ( Accuracy) : 0.630472719669342, Val Metric (accuracy) : 0.6266000270843506
# Epoch : 5/20, Train Loss : 1.38560081632049, Train Metric ( Accuracy) : 0.6302182078361511, Val Metric (accuracy) : 0.6269999742507935
# Epoch : 6/20, Train Loss : 1.37575270180349, Train Metric ( Accuracy) : 0.6311272978782654, Val Metric (accuracy) : 0.6269999742507935
# Epoch : 7/20, Train Loss : 1.366510679324468, Train Metric ( Accuracy) : 0.6316182017326355, Val Metric (accuracy) : 0.6281999945640564
# Epoch : 8/20, Train Loss : 1.3569700320561726, Train Metric ( Accuracy) : 0.6321818232536316, Val Metric (accuracy) : 0.6290000081062317
# Epoch : 9/20, Train Loss : 1.3478034182831093, Train Metric ( Accuracy) : 0.6327454447746277, Val Metric (accuracy) : 0.6287999749183655
# Epoch : 10/20, Train Loss : 1.3388878206411998, Train Metric ( Accuracy) : 0.6335999965667725, Val Metric (accuracy) : 0.628600001335144
# Epoch : 11/20, Train Loss : 1.330063388303474, Train Metric ( Accuracy) : 0.6335999965667725, Val Metric (accuracy) : 0.628600001335144
# Epoch : 12/20, Train Loss : 1.3213341489986137, Train Metric ( Accuracy) : 0.6336908936500549, Val Metric (accuracy) : 0.6287999749183655
# Epoch : 13/20, Train Loss : 1.3132973986643333, Train Metric ( Accuracy) : 0.6345454454421997, Val Metric (accuracy) : 0.6290000081062317
# Epoch : 14/20, Train Loss : 1.3050580278590873, Train Metric ( Accuracy) : 0.6348727345466614, Val Metric (accuracy) : 0.6291999816894531
# Epoch : 15/20, Train Loss : 1.2967915303177304, Train Metric ( Accuracy) : 0.6355272531509399, Val Metric (accuracy) : 0.6290000081062317
# Epoch : 16/20, Train Loss : 1.2890026414835896, Train Metric ( Accuracy) : 0.6358000040054321, Val Metric (accuracy) : 0.6294000148773193
# Epoch : 17/20, Train Loss : 1.2806011029967554, Train Metric ( Accuracy) : 0.6359999775886536, Val Metric (accuracy) : 0.6302000284194946
# Epoch : 18/20, Train Loss : 1.2729647645243891, Train Metric ( Accuracy) : 0.6362181901931763, Val Metric (accuracy) : 0.6308000087738037
# Epoch : 19/20, Train Loss : 1.2655568994857647, Train Metric ( Accuracy) : 0.637327253818512, Val Metric (accuracy) : 0.6304000020027161
# Epoch : 20/20, Train Loss : 1.2579718541215967, Train Metric ( Accuracy) : 0.6381818056106567, Val Metric (accuracy) : 0.6312000155448914
# Epoch : 1/20, Train Loss : 1.2504969272348616, Train Metric ( Accuracy) : 0.6382545232772827, Val Metric (accuracy) : 0.6309999823570251
# Epoch : 2/20, Train Loss : 1.2432277037037744, Train Metric ( Accuracy) : 0.6389272809028625, Val Metric (accuracy) : 0.6312000155448914
# Epoch : 3/20, Train Loss : 1.2365226867022339, Train Metric ( Accuracy) : 0.6394909024238586, Val Metric (accuracy) : 0.6313999891281128
# Epoch : 4/20, Train Loss : 1.2297612009225067, Train Metric ( Accuracy) : 0.6403090953826904, Val Metric (accuracy) : 0.631600022315979
# Epoch : 5/20, Train Loss : 1.2221005923218198, Train Metric ( Accuracy) : 0.6414181590080261, Val Metric (accuracy) : 0.6313999891281128
# Epoch : 6/20, Train Loss : 1.2158425174377583, Train Metric ( Accuracy) : 0.6417818069458008, Val Metric (accuracy) : 0.6313999891281128
# Epoch : 7/20, Train Loss : 1.2093369585496407, Train Metric ( Accuracy) : 0.642090916633606, Val Metric (accuracy) : 0.6322000026702881
# Epoch : 8/20, Train Loss : 1.2030028281388458, Train Metric ( Accuracy) : 0.6422545313835144, Val Metric (accuracy) : 0.6327999830245972
# Epoch : 9/20, Train Loss : 1.1960314931692901, Train Metric ( Accuracy) : 0.6434545516967773, Val Metric (accuracy) : 0.6331999897956848
# Epoch : 10/20, Train Loss : 1.1900513150073864, Train Metric ( Accuracy) : 0.6433454751968384, Val Metric (accuracy) : 0.6340000033378601
# Epoch : 11/20, Train Loss : 1.18411429171209, Train Metric ( Accuracy) : 0.6438363790512085, Val Metric (accuracy) : 0.6345999836921692
# Epoch : 12/20, Train Loss : 1.177795437750993, Train Metric ( Accuracy) : 0.644563615322113, Val Metric (accuracy) : 0.6353999972343445
# Epoch : 13/20, Train Loss : 1.1720325494254078, Train Metric ( Accuracy) : 0.6447454690933228, Val Metric (accuracy) : 0.6363999843597412
# Epoch : 14/20, Train Loss : 1.1660244531101651, Train Metric ( Accuracy) : 0.6454363465309143, Val Metric (accuracy) : 0.6371999979019165
# Epoch : 15/20, Train Loss : 1.1608582414962627, Train Metric ( Accuracy) : 0.645545482635498, Val Metric (accuracy) : 0.6385999917984009
# Epoch : 16/20, Train Loss : 1.1547469209741663, Train Metric ( Accuracy) : 0.6461818218231201, Val Metric (accuracy) : 0.6388000249862671
# Epoch : 17/20, Train Loss : 1.1490420599778493, Train Metric ( Accuracy) : 0.6468545198440552, Val Metric (accuracy) : 0.63919997215271
# Epoch : 18/20, Train Loss : 1.1437079531175118, Train Metric ( Accuracy) : 0.6472545266151428, Val Metric (accuracy) : 0.6389999985694885
# Epoch : 19/20, Train Loss : 1.1382159954971738, Train Metric ( Accuracy) : 0.6477454304695129, Val Metric (accuracy) : 0.6389999985694885
# Epoch : 20/20, Train Loss : 1.132999465421394, Train Metric ( Accuracy) : 0.647672712802887, Val Metric (accuracy) : 0.6399999856948853
# Epoch : 1/20, Train Loss : 1.1278487024483856, Train Metric ( Accuracy) : 0.6482545733451843, Val Metric (accuracy) : 0.6398000121116638
# Epoch : 2/20, Train Loss : 1.122670077615314, Train Metric ( Accuracy) : 0.6488363742828369, Val Metric (accuracy) : 0.6395999789237976
# Epoch : 3/20, Train Loss : 1.1175187395678625, Train Metric ( Accuracy) : 0.6491090655326843, Val Metric (accuracy) : 0.6403999924659729
# Epoch : 4/20, Train Loss : 1.1130128502845764, Train Metric ( Accuracy) : 0.6499636173248291, Val Metric (accuracy) : 0.6403999924659729
# Epoch : 5/20, Train Loss : 1.1077967882156372, Train Metric ( Accuracy) : 0.6503454446792603, Val Metric (accuracy) : 0.6407999992370605
# Epoch : 6/20, Train Loss : 1.1030662688944075, Train Metric ( Accuracy) : 0.6506181955337524, Val Metric (accuracy) : 0.6407999992370605
# Epoch : 7/20, Train Loss : 1.0988737675878737, Train Metric ( Accuracy) : 0.6517272591590881, Val Metric (accuracy) : 0.6413999795913696
# Epoch : 8/20, Train Loss : 1.0936142559404727, Train Metric ( Accuracy) : 0.6522908806800842, Val Metric (accuracy) : 0.6420000195503235
# Epoch : 9/20, Train Loss : 1.0891997185018327, Train Metric ( Accuracy) : 0.6525999903678894, Val Metric (accuracy) : 0.6425999999046326
# Epoch : 10/20, Train Loss : 1.0846182847464527, Train Metric ( Accuracy) : 0.6532363891601562, Val Metric (accuracy) : 0.6431999802589417
# Epoch : 11/20, Train Loss : 1.080619239144855, Train Metric ( Accuracy) : 0.6536727547645569, Val Metric (accuracy) : 0.6439999938011169
# Epoch : 12/20, Train Loss : 1.076140542825063, Train Metric ( Accuracy) : 0.6543272733688354, Val Metric (accuracy) : 0.644599974155426
# Epoch : 13/20, Train Loss : 1.0714999945075423, Train Metric ( Accuracy) : 0.654945433139801, Val Metric (accuracy) : 0.6449999809265137
# Epoch : 14/20, Train Loss : 1.0671948867815513, Train Metric ( Accuracy) : 0.6554181575775146, Val Metric (accuracy) : 0.645799994468689
# Epoch : 15/20, Train Loss : 1.0632019605901506, Train Metric ( Accuracy) : 0.6560545563697815, Val Metric (accuracy) : 0.6460000276565552
# Epoch : 16/20, Train Loss : 1.0590662597506135, Train Metric ( Accuracy) : 0.6563090682029724, Val Metric (accuracy) : 0.6462000012397766
# Epoch : 17/20, Train Loss : 1.0550624971036557, Train Metric ( Accuracy) : 0.6570000052452087, Val Metric (accuracy) : 0.6478000283241272
# Epoch : 18/20, Train Loss : 1.0507975044073883, Train Metric ( Accuracy) : 0.6578545570373535, Val Metric (accuracy) : 0.6481999754905701
# Epoch : 19/20, Train Loss : 1.0472235436792727, Train Metric ( Accuracy) : 0.6584363579750061, Val Metric (accuracy) : 0.6484000086784363
# Epoch : 20/20, Train Loss : 1.043349172782015, Train Metric ( Accuracy) : 0.6585454344749451, Val Metric (accuracy) : 0.6488000154495239
# Epoch : 1/20, Train Loss : 1.0395271844334073, Train Metric ( Accuracy) : 0.6587818264961243, Val Metric (accuracy) : 0.6488000154495239
# Epoch : 2/20, Train Loss : 1.0358246288917683, Train Metric ( Accuracy) : 0.6596545577049255, Val Metric (accuracy) : 0.6492000222206116
# Epoch : 3/20, Train Loss : 1.031782850071236, Train Metric ( Accuracy) : 0.6597999930381775, Val Metric (accuracy) : 0.6492000222206116
# Epoch : 4/20, Train Loss : 1.028313743295493, Train Metric ( Accuracy) : 0.6606545448303223, Val Metric (accuracy) : 0.6496000289916992
# Epoch : 5/20, Train Loss : 1.0242981883110824, Train Metric ( Accuracy) : 0.6610727310180664, Val Metric (accuracy) : 0.6499999761581421
# Epoch : 6/20, Train Loss : 1.02105239144078, Train Metric ( Accuracy) : 0.6613090634346008, Val Metric (accuracy) : 0.6503999829292297
# Epoch : 7/20, Train Loss : 1.017223878591149, Train Metric ( Accuracy) : 0.6618727445602417, Val Metric (accuracy) : 0.650600016117096
# Epoch : 8/20, Train Loss : 1.014167054935738, Train Metric ( Accuracy) : 0.6619818210601807, Val Metric (accuracy) : 0.6520000100135803
# Epoch : 9/20, Train Loss : 1.0107404694513038, Train Metric ( Accuracy) : 0.6625999808311462, Val Metric (accuracy) : 0.652999997138977
# Epoch : 10/20, Train Loss : 1.006964549422264, Train Metric ( Accuracy) : 0.6630545258522034, Val Metric (accuracy) : 0.6531999707221985
# Epoch : 11/20, Train Loss : 1.0038427997518469, Train Metric ( Accuracy) : 0.6633272767066956, Val Metric (accuracy) : 0.6531999707221985
# Epoch : 12/20, Train Loss : 1.000689771440294, Train Metric ( Accuracy) : 0.6638363599777222, Val Metric (accuracy) : 0.6535999774932861
# Epoch : 13/20, Train Loss : 0.9977703077925576, Train Metric ( Accuracy) : 0.6640727519989014, Val Metric (accuracy) : 0.6535999774932861
# Epoch : 14/20, Train Loss : 0.9939613391955694, Train Metric ( Accuracy) : 0.6645272970199585, Val Metric (accuracy) : 0.6547999978065491
# Epoch : 15/20, Train Loss : 0.9917642264454453, Train Metric ( Accuracy) : 0.6646727323532104, Val Metric (accuracy) : 0.6552000045776367
# Epoch : 16/20, Train Loss : 0.988394867490839, Train Metric ( Accuracy) : 0.6655091047286987, Val Metric (accuracy) : 0.6561999917030334
# Epoch : 17/20, Train Loss : 0.984692586240945, Train Metric ( Accuracy) : 0.6660000085830688, Val Metric (accuracy) : 0.656000018119812
# Epoch : 18/20, Train Loss : 0.982081491638113, Train Metric ( Accuracy) : 0.6663636565208435, Val Metric (accuracy) : 0.6564000248908997
# Epoch : 19/20, Train Loss : 0.9791181043342307, Train Metric ( Accuracy) : 0.6668909192085266, Val Metric (accuracy) : 0.6574000120162964
# Epoch : 20/20, Train Loss : 0.9756171708857572, Train Metric ( Accuracy) : 0.6672000288963318, Val Metric (accuracy) : 0.657800018787384
# Epoch : 1/20, Train Loss : 0.9733320033108747, Train Metric ( Accuracy) : 0.6679454445838928, Val Metric (accuracy) : 0.6583999991416931
# Epoch : 2/20, Train Loss : 0.9698176439161654, Train Metric ( Accuracy) : 0.668363630771637, Val Metric (accuracy) : 0.6585999727249146
# Epoch : 3/20, Train Loss : 0.9673395614933085, Train Metric ( Accuracy) : 0.6687090992927551, Val Metric (accuracy) : 0.6592000126838684
# Epoch : 4/20, Train Loss : 0.964639953992985, Train Metric ( Accuracy) : 0.6693090796470642, Val Metric (accuracy) : 0.6589999794960022
# Epoch : 5/20, Train Loss : 0.96141675721716, Train Metric ( Accuracy) : 0.6698908805847168, Val Metric (accuracy) : 0.659600019454956
# Epoch : 6/20, Train Loss : 0.9588429811928008, Train Metric ( Accuracy) : 0.6703454256057739, Val Metric (accuracy) : 0.6601999998092651
# Epoch : 7/20, Train Loss : 0.9563331581928112, Train Metric ( Accuracy) : 0.6711272597312927, Val Metric (accuracy) : 0.6600000262260437
# Epoch : 8/20, Train Loss : 0.9534411358612555, Train Metric ( Accuracy) : 0.6715454459190369, Val Metric (accuracy) : 0.6614000201225281
# Epoch : 9/20, Train Loss : 0.9510095147071062, Train Metric ( Accuracy) : 0.6715454459190369, Val Metric (accuracy) : 0.6621999740600586
# Epoch : 10/20, Train Loss : 0.9484227448701859, Train Metric ( Accuracy) : 0.6723272800445557, Val Metric (accuracy) : 0.6625999808311462
# Epoch : 11/20, Train Loss : 0.9456308787619626, Train Metric ( Accuracy) : 0.6723999977111816, Val Metric (accuracy) : 0.6632000207901001
# Epoch : 12/20, Train Loss : 0.9430238085764425, Train Metric ( Accuracy) : 0.6732000112533569, Val Metric (accuracy) : 0.6639999747276306
# Epoch : 13/20, Train Loss : 0.9407954491950847, Train Metric ( Accuracy) : 0.6728545427322388, Val Metric (accuracy) : 0.6650000214576721
# Epoch : 14/20, Train Loss : 0.9389773723151948, Train Metric ( Accuracy) : 0.6735818386077881, Val Metric (accuracy) : 0.6651999950408936
# Epoch : 15/20, Train Loss : 0.9356970229634533, Train Metric ( Accuracy) : 0.6740727424621582, Val Metric (accuracy) : 0.6656000018119812
# Epoch : 16/20, Train Loss : 0.9335623057904067, Train Metric ( Accuracy) : 0.6746363639831543, Val Metric (accuracy) : 0.6651999950408936
# Epoch : 17/20, Train Loss : 0.9314033344939903, Train Metric ( Accuracy) : 0.6748727560043335, Val Metric (accuracy) : 0.6654000282287598
# Epoch : 18/20, Train Loss : 0.9289848627867522, Train Metric ( Accuracy) : 0.6752363443374634, Val Metric (accuracy) : 0.6660000085830688
# Epoch : 19/20, Train Loss : 0.9262052608860863, Train Metric ( Accuracy) : 0.6761999726295471, Val Metric (accuracy) : 0.6656000018119812
# Epoch : 20/20, Train Loss : 0.9242735659634626, Train Metric ( Accuracy) : 0.6763091087341309, Val Metric (accuracy) : 0.6664000153541565
# Epoch : 1/20, Train Loss : 0.9215889175732931, Train Metric ( Accuracy) : 0.676763653755188, Val Metric (accuracy) : 0.6664000153541565
# Epoch : 2/20, Train Loss : 0.9192698288846899, Train Metric ( Accuracy) : 0.6773090958595276, Val Metric (accuracy) : 0.6672000288963318
# Epoch : 3/20, Train Loss : 0.9171169129786668, Train Metric ( Accuracy) : 0.6779817938804626, Val Metric (accuracy) : 0.6674000024795532
# Epoch : 4/20, Train Loss : 0.915023355572312, Train Metric ( Accuracy) : 0.6783454418182373, Val Metric (accuracy) : 0.6682000160217285
# Epoch : 5/20, Train Loss : 0.9122138691169245, Train Metric ( Accuracy) : 0.6789273023605347, Val Metric (accuracy) : 0.6682000160217285
# Epoch : 6/20, Train Loss : 0.9105302454144867, Train Metric ( Accuracy) : 0.6791999936103821, Val Metric (accuracy) : 0.6693999767303467
# Epoch : 7/20, Train Loss : 0.9088317144800115, Train Metric ( Accuracy) : 0.6797817945480347, Val Metric (accuracy) : 0.670199990272522
# Epoch : 8/20, Train Loss : 0.9066389467981126, Train Metric ( Accuracy) : 0.6798545718193054, Val Metric (accuracy) : 0.6705999970436096
# Epoch : 9/20, Train Loss : 0.9040322645946786, Train Metric ( Accuracy) : 0.680363655090332, Val Metric (accuracy) : 0.6711999773979187
# Epoch : 10/20, Train Loss : 0.9022050157741264, Train Metric ( Accuracy) : 0.6810727119445801, Val Metric (accuracy) : 0.6718000173568726
# Epoch : 11/20, Train Loss : 0.8999463441195311, Train Metric ( Accuracy) : 0.6814363598823547, Val Metric (accuracy) : 0.6723999977111816
# Epoch : 12/20, Train Loss : 0.8975169984278856, Train Metric ( Accuracy) : 0.6821091175079346, Val Metric (accuracy) : 0.6733999848365784
# Epoch : 13/20, Train Loss : 0.8957390343701398, Train Metric ( Accuracy) : 0.6825454831123352, Val Metric (accuracy) : 0.6736000180244446
# Epoch : 14/20, Train Loss : 0.8937072511072512, Train Metric ( Accuracy) : 0.6826727390289307, Val Metric (accuracy) : 0.6741999983787537
# Epoch : 15/20, Train Loss : 0.8920540655100787, Train Metric ( Accuracy) : 0.6832363605499268, Val Metric (accuracy) : 0.6746000051498413
# Epoch : 16/20, Train Loss : 0.8899721486700906, Train Metric ( Accuracy) : 0.6835818290710449, Val Metric (accuracy) : 0.6746000051498413
# Epoch : 17/20, Train Loss : 0.8882173835127442, Train Metric ( Accuracy) : 0.684145450592041, Val Metric (accuracy) : 0.6747999787330627
# Epoch : 18/20, Train Loss : 0.8859396935613068, Train Metric ( Accuracy) : 0.6840909123420715, Val Metric (accuracy) : 0.6747999787330627
# Epoch : 19/20, Train Loss : 0.8837816301319334, Train Metric ( Accuracy) : 0.6846181750297546, Val Metric (accuracy) : 0.675599992275238
# Epoch : 20/20, Train Loss : 0.8824262999826007, Train Metric ( Accuracy) : 0.6852181553840637, Val Metric (accuracy) : 0.6765999794006348
# Epoch : 1/20, Train Loss : 0.8806138331139529, Train Metric ( Accuracy) : 0.6853636503219604, Val Metric (accuracy) : 0.6782000064849854
# Epoch : 2/20, Train Loss : 0.8785828070508109, Train Metric ( Accuracy) : 0.6858000159263611, Val Metric (accuracy) : 0.678600013256073
# Epoch : 3/20, Train Loss : 0.8766717623781275, Train Metric ( Accuracy) : 0.6863454580307007, Val Metric (accuracy) : 0.678600013256073
# Epoch : 4/20, Train Loss : 0.874308133566821, Train Metric ( Accuracy) : 0.6864363551139832, Val Metric (accuracy) : 0.6791999936103821
# Epoch : 5/20, Train Loss : 0.8729836791753769, Train Metric ( Accuracy) : 0.6868909001350403, Val Metric (accuracy) : 0.6796000003814697
# Epoch : 6/20, Train Loss : 0.8714257070311794, Train Metric ( Accuracy) : 0.6872545480728149, Val Metric (accuracy) : 0.680400013923645
# Epoch : 7/20, Train Loss : 0.8694766737796642, Train Metric ( Accuracy) : 0.6879090666770935, Val Metric (accuracy) : 0.6808000206947327
# Epoch : 8/20, Train Loss : 0.8682038883368174, Train Metric ( Accuracy) : 0.6881090998649597, Val Metric (accuracy) : 0.6812000274658203
# Epoch : 9/20, Train Loss : 0.866165034196995, Train Metric ( Accuracy) : 0.6887999773025513, Val Metric (accuracy) : 0.6814000010490417
# Epoch : 10/20, Train Loss : 0.864378985983354, Train Metric ( Accuracy) : 0.6887999773025513, Val Metric (accuracy) : 0.6818000078201294
# Epoch : 11/20, Train Loss : 0.86318329638905, Train Metric ( Accuracy) : 0.6891999840736389, Val Metric (accuracy) : 0.6830000281333923
# Epoch : 12/20, Train Loss : 0.8615833912734632, Train Metric ( Accuracy) : 0.6898545622825623, Val Metric (accuracy) : 0.6830000281333923
# Epoch : 13/20, Train Loss : 0.8590746659923483, Train Metric ( Accuracy) : 0.6902727484703064, Val Metric (accuracy) : 0.6833999752998352
# Epoch : 14/20, Train Loss : 0.8577116186972018, Train Metric ( Accuracy) : 0.6904545426368713, Val Metric (accuracy) : 0.6832000017166138
# Epoch : 15/20, Train Loss : 0.8562209909712827, Train Metric ( Accuracy) : 0.690818190574646, Val Metric (accuracy) : 0.6841999888420105
# Epoch : 16/20, Train Loss : 0.8542771024836434, Train Metric ( Accuracy) : 0.6915090680122375, Val Metric (accuracy) : 0.6845999956130981
# Epoch : 17/20, Train Loss : 0.8528007164045617, Train Metric ( Accuracy) : 0.6916727423667908, Val Metric (accuracy) : 0.6848000288009644
# Epoch : 18/20, Train Loss : 0.8513101631844485, Train Metric ( Accuracy) : 0.6921454668045044, Val Metric (accuracy) : 0.6851999759674072
# Epoch : 19/20, Train Loss : 0.8503934746539151, Train Metric ( Accuracy) : 0.6927454471588135, Val Metric (accuracy) : 0.6844000220298767
# Epoch : 20/20, Train Loss : 0.8483801395804794, Train Metric ( Accuracy) : 0.69276362657547, Val Metric (accuracy) : 0.6855999827384949
# Epoch : 1/20, Train Loss : 0.8473051863688009, Train Metric ( Accuracy) : 0.6932908892631531, Val Metric (accuracy) : 0.6859999895095825
# Epoch : 2/20, Train Loss : 0.8452799403005176, Train Metric ( Accuracy) : 0.6939636468887329, Val Metric (accuracy) : 0.6858000159263611
# Epoch : 3/20, Train Loss : 0.843966895783389, Train Metric ( Accuracy) : 0.6944363713264465, Val Metric (accuracy) : 0.6862000226974487
# Epoch : 4/20, Train Loss : 0.8421878842292009, Train Metric ( Accuracy) : 0.694527268409729, Val Metric (accuracy) : 0.6859999895095825
# Epoch : 5/20, Train Loss : 0.8409098723420391, Train Metric ( Accuracy) : 0.6950181722640991, Val Metric (accuracy) : 0.6855999827384949
# Epoch : 6/20, Train Loss : 0.8393693086173799, Train Metric ( Accuracy) : 0.6952909231185913, Val Metric (accuracy) : 0.6862000226974487
# Epoch : 7/20, Train Loss : 0.8376197781827714, Train Metric ( Accuracy) : 0.6953999996185303, Val Metric (accuracy) : 0.6877999901771545
# Epoch : 8/20, Train Loss : 0.8361762486122273, Train Metric ( Accuracy) : 0.6961636543273926, Val Metric (accuracy) : 0.6880000233650208
# Epoch : 9/20, Train Loss : 0.8351540179164322, Train Metric ( Accuracy) : 0.696363627910614, Val Metric (accuracy) : 0.6883999705314636
# Epoch : 10/20, Train Loss : 0.833625727781543, Train Metric ( Accuracy) : 0.6965818405151367, Val Metric (accuracy) : 0.6899999976158142
# Epoch : 11/20, Train Loss : 0.8319972151959384, Train Metric ( Accuracy) : 0.6970363855361938, Val Metric (accuracy) : 0.6898000240325928
# Epoch : 12/20, Train Loss : 0.8304975032806396, Train Metric ( Accuracy) : 0.6976727247238159, Val Metric (accuracy) : 0.6904000043869019
# Epoch : 13/20, Train Loss : 0.8292087173020398, Train Metric ( Accuracy) : 0.6977090835571289, Val Metric (accuracy) : 0.6899999976158142
# Epoch : 14/20, Train Loss : 0.8279671266123101, Train Metric ( Accuracy) : 0.6982181668281555, Val Metric (accuracy) : 0.6904000043869019
# Epoch : 15/20, Train Loss : 0.8261973598489055, Train Metric ( Accuracy) : 0.6983636617660522, Val Metric (accuracy) : 0.6905999779701233
# Epoch : 16/20, Train Loss : 0.824968574223695, Train Metric ( Accuracy) : 0.6990181803703308, Val Metric (accuracy) : 0.6909999847412109
# Epoch : 17/20, Train Loss : 0.8239245122229611, Train Metric ( Accuracy) : 0.699327290058136, Val Metric (accuracy) : 0.6917999982833862
# Epoch : 18/20, Train Loss : 0.8224107750036098, Train Metric ( Accuracy) : 0.6997818350791931, Val Metric (accuracy) : 0.6913999915122986
# Epoch : 19/20, Train Loss : 0.8213403307729297, Train Metric ( Accuracy) : 0.6999818086624146, Val Metric (accuracy) : 0.6913999915122986
# Epoch : 20/20, Train Loss : 0.8199654497482158, Train Metric ( Accuracy) : 0.7003454566001892, Val Metric (accuracy) : 0.6923999786376953
# Epoch : 1/20, Train Loss : 0.8186297907873437, Train Metric ( Accuracy) : 0.7008000016212463, Val Metric (accuracy) : 0.6931999921798706
# Epoch : 2/20, Train Loss : 0.8177860699318074, Train Metric ( Accuracy) : 0.701090931892395, Val Metric (accuracy) : 0.6934000253677368
# Epoch : 3/20, Train Loss : 0.8159831491885362, Train Metric ( Accuracy) : 0.7015091180801392, Val Metric (accuracy) : 0.6931999921798706
# Epoch : 4/20, Train Loss : 0.814857432687724, Train Metric ( Accuracy) : 0.7020363807678223, Val Metric (accuracy) : 0.6940000057220459
# Epoch : 5/20, Train Loss : 0.8136794969991401, Train Metric ( Accuracy) : 0.7022727131843567, Val Metric (accuracy) : 0.694599986076355
# Epoch : 6/20, Train Loss : 0.8121913246534489, Train Metric ( Accuracy) : 0.703000009059906, Val Metric (accuracy) : 0.6940000057220459
# Epoch : 7/20, Train Loss : 0.8114301794105105, Train Metric ( Accuracy) : 0.703109085559845, Val Metric (accuracy) : 0.6952000260353088
# Epoch : 8/20, Train Loss : 0.810075498841427, Train Metric ( Accuracy) : 0.7032727003097534, Val Metric (accuracy) : 0.6944000124931335
# Epoch : 9/20, Train Loss : 0.8084937251276441, Train Metric ( Accuracy) : 0.7039818167686462, Val Metric (accuracy) : 0.6944000124931335
# Epoch : 10/20, Train Loss : 0.8070548855596118, Train Metric ( Accuracy) : 0.7042182087898254, Val Metric (accuracy) : 0.694599986076355
# Epoch : 11/20, Train Loss : 0.8063901513814926, Train Metric ( Accuracy) : 0.7046363353729248, Val Metric (accuracy) : 0.6948000192642212
# Epoch : 12/20, Train Loss : 0.8054039279619852, Train Metric ( Accuracy) : 0.7044000029563904, Val Metric (accuracy) : 0.6949999928474426
# Epoch : 13/20, Train Loss : 0.8036389290182678, Train Metric ( Accuracy) : 0.7051454782485962, Val Metric (accuracy) : 0.6953999996185303
# Epoch : 14/20, Train Loss : 0.8027915485479213, Train Metric ( Accuracy) : 0.7053090929985046, Val Metric (accuracy) : 0.6953999996185303
# Epoch : 15/20, Train Loss : 0.801355747712983, Train Metric ( Accuracy) : 0.7057999968528748, Val Metric (accuracy) : 0.6955999732017517
# Epoch : 16/20, Train Loss : 0.8001447949144576, Train Metric ( Accuracy) : 0.7062000036239624, Val Metric (accuracy) : 0.6958000063896179
# Epoch : 17/20, Train Loss : 0.7988937734453766, Train Metric ( Accuracy) : 0.7062909007072449, Val Metric (accuracy) : 0.6966000199317932
# Epoch : 18/20, Train Loss : 0.7976147262034593, Train Metric ( Accuracy) : 0.70660001039505, Val Metric (accuracy) : 0.6970000267028809
# Epoch : 19/20, Train Loss : 0.7967056356094502, Train Metric ( Accuracy) : 0.7071272730827332, Val Metric (accuracy) : 0.6959999799728394
# Epoch : 20/20, Train Loss : 0.7959615207380719, Train Metric ( Accuracy) : 0.7071636319160461, Val Metric (accuracy) : 0.696399986743927
# Epoch : 1/20, Train Loss : 0.7945127597561589, Train Metric ( Accuracy) : 0.7077090740203857, Val Metric (accuracy) : 0.6977999806404114
# Epoch : 2/20, Train Loss : 0.7937407973739836, Train Metric ( Accuracy) : 0.7080181837081909, Val Metric (accuracy) : 0.6967999935150146
# Epoch : 3/20, Train Loss : 0.7923325129129268, Train Metric ( Accuracy) : 0.7083272933959961, Val Metric (accuracy) : 0.6966000199317932
# Epoch : 4/20, Train Loss : 0.7913156946500143, Train Metric ( Accuracy) : 0.7087636590003967, Val Metric (accuracy) : 0.696399986743927
# Epoch : 5/20, Train Loss : 0.7904340630328214, Train Metric ( Accuracy) : 0.7091818451881409, Val Metric (accuracy) : 0.6973999738693237
# Epoch : 6/20, Train Loss : 0.7889655662907494, Train Metric ( Accuracy) : 0.7093454599380493, Val Metric (accuracy) : 0.6984000205993652
# Epoch : 7/20, Train Loss : 0.7888054980172051, Train Metric ( Accuracy) : 0.7100363373756409, Val Metric (accuracy) : 0.6985999941825867
# Epoch : 8/20, Train Loss : 0.7865833209620582, Train Metric ( Accuracy) : 0.7102181911468506, Val Metric (accuracy) : 0.698199987411499
# Epoch : 9/20, Train Loss : 0.7857660281437414, Train Metric ( Accuracy) : 0.7103090882301331, Val Metric (accuracy) : 0.6990000009536743
# Epoch : 10/20, Train Loss : 0.7845760727370227, Train Metric ( Accuracy) : 0.7110182046890259, Val Metric (accuracy) : 0.6985999941825867
# Epoch : 11/20, Train Loss : 0.7834063365503594, Train Metric ( Accuracy) : 0.711654543876648, Val Metric (accuracy) : 0.6990000009536743
# Epoch : 12/20, Train Loss : 0.782847167717086, Train Metric ( Accuracy) : 0.7116909027099609, Val Metric (accuracy) : 0.6991999745368958
# Epoch : 13/20, Train Loss : 0.7815807787356553, Train Metric ( Accuracy) : 0.7120000123977661, Val Metric (accuracy) : 0.6991999745368958
# Epoch : 14/20, Train Loss : 0.7807010903402611, Train Metric ( Accuracy) : 0.7124000191688538, Val Metric (accuracy) : 0.6995999813079834
# Epoch : 15/20, Train Loss : 0.7795794523424573, Train Metric ( Accuracy) : 0.7127818465232849, Val Metric (accuracy) : 0.6998000144958496
# Epoch : 16/20, Train Loss : 0.7786017667364191, Train Metric ( Accuracy) : 0.7133636474609375, Val Metric (accuracy) : 0.6998000144958496
# Epoch : 17/20, Train Loss : 0.7779579703454618, Train Metric ( Accuracy) : 0.7138363718986511, Val Metric (accuracy) : 0.699999988079071
# Epoch : 18/20, Train Loss : 0.7769584175613191, Train Metric ( Accuracy) : 0.7142181992530823, Val Metric (accuracy) : 0.7003999948501587
# Epoch : 19/20, Train Loss : 0.7753943392524013, Train Metric ( Accuracy) : 0.7141090631484985, Val Metric (accuracy) : 0.7021999955177307
# Epoch : 20/20, Train Loss : 0.7750973585579131, Train Metric ( Accuracy) : 0.7145636081695557, Val Metric (accuracy) : 0.7024000287055969
# Epoch : 1/20, Train Loss : 0.7736879162214421, Train Metric ( Accuracy) : 0.7152363657951355, Val Metric (accuracy) : 0.703000009059906
# Epoch : 2/20, Train Loss : 0.7724277664113928, Train Metric ( Accuracy) : 0.7156181931495667, Val Metric (accuracy) : 0.7034000158309937
# Epoch : 3/20, Train Loss : 0.7720603777302636, Train Metric ( Accuracy) : 0.7158181667327881, Val Metric (accuracy) : 0.7039999961853027
# Epoch : 4/20, Train Loss : 0.7706704051406296, Train Metric ( Accuracy) : 0.7161272764205933, Val Metric (accuracy) : 0.704800009727478
# Epoch : 5/20, Train Loss : 0.7695475673234021, Train Metric ( Accuracy) : 0.7167999744415283, Val Metric (accuracy) : 0.7049999833106995
# Epoch : 6/20, Train Loss : 0.7689281133589921, Train Metric ( Accuracy) : 0.717199981212616, Val Metric (accuracy) : 0.7049999833106995
# Epoch : 7/20, Train Loss : 0.7681063805465345, Train Metric ( Accuracy) : 0.7175454497337341, Val Metric (accuracy) : 0.7053999900817871
# Epoch : 8/20, Train Loss : 0.7668340851863226, Train Metric ( Accuracy) : 0.7179818153381348, Val Metric (accuracy) : 0.70660001039505
# Epoch : 9/20, Train Loss : 0.7666181447329344, Train Metric ( Accuracy) : 0.7183818221092224, Val Metric (accuracy) : 0.7059999704360962
# Epoch : 10/20, Train Loss : 0.7651241013297329, Train Metric ( Accuracy) : 0.7188727259635925, Val Metric (accuracy) : 0.7070000171661377
# Epoch : 11/20, Train Loss : 0.7642853226926591, Train Metric ( Accuracy) : 0.7191272974014282, Val Metric (accuracy) : 0.7074000239372253
# Epoch : 12/20, Train Loss : 0.7631033245060179, Train Metric ( Accuracy) : 0.7195090651512146, Val Metric (accuracy) : 0.7074000239372253
# Epoch : 13/20, Train Loss : 0.7625132158950523, Train Metric ( Accuracy) : 0.7199272513389587, Val Metric (accuracy) : 0.7075999975204468
# Epoch : 14/20, Train Loss : 0.7616438109565664, Train Metric ( Accuracy) : 0.7206545472145081, Val Metric (accuracy) : 0.7075999975204468
# Epoch : 15/20, Train Loss : 0.7606033710417924, Train Metric ( Accuracy) : 0.7209454774856567, Val Metric (accuracy) : 0.7075999975204468
# Epoch : 16/20, Train Loss : 0.7591817130645117, Train Metric ( Accuracy) : 0.7212545275688171, Val Metric (accuracy) : 0.7092000246047974
# Epoch : 17/20, Train Loss : 0.7587705409085309, Train Metric ( Accuracy) : 0.7217090725898743, Val Metric (accuracy) : 0.7095999717712402
# Epoch : 18/20, Train Loss : 0.7575470451955442, Train Metric ( Accuracy) : 0.7221636176109314, Val Metric (accuracy) : 0.7102000117301941
# Epoch : 19/20, Train Loss : 0.7568740883359203, Train Metric ( Accuracy) : 0.7228000164031982, Val Metric (accuracy) : 0.7098000049591064
# Epoch : 20/20, Train Loss : 0.755902013844914, Train Metric ( Accuracy) : 0.7227091193199158, Val Metric (accuracy) : 0.7099999785423279
# Epoch : 1/20, Train Loss : 0.7554486095905304, Train Metric ( Accuracy) : 0.723654568195343, Val Metric (accuracy) : 0.7107999920845032
# Epoch : 2/20, Train Loss : 0.7541373984681236, Train Metric ( Accuracy) : 0.7241818308830261, Val Metric (accuracy) : 0.7107999920845032
# Epoch : 3/20, Train Loss : 0.7538331139970709, Train Metric ( Accuracy) : 0.7242181897163391, Val Metric (accuracy) : 0.7111999988555908
# Epoch : 4/20, Train Loss : 0.7523857084689317, Train Metric ( Accuracy) : 0.7248545289039612, Val Metric (accuracy) : 0.7121999859809875
# Epoch : 5/20, Train Loss : 0.7513116355295535, Train Metric ( Accuracy) : 0.7249454259872437, Val Metric (accuracy) : 0.7139999866485596
# Epoch : 6/20, Train Loss : 0.7509388642178642, Train Metric ( Accuracy) : 0.7254727482795715, Val Metric (accuracy) : 0.7131999731063843
# Epoch : 7/20, Train Loss : 0.7498263788444025, Train Metric ( Accuracy) : 0.7260000109672546, Val Metric (accuracy) : 0.7135999798774719
# Epoch : 8/20, Train Loss : 0.7492125326836551, Train Metric ( Accuracy) : 0.7263091206550598, Val Metric (accuracy) : 0.7139999866485596
# Epoch : 9/20, Train Loss : 0.7493817966293406, Train Metric ( Accuracy) : 0.7262363433837891, Val Metric (accuracy) : 0.7143999934196472
# Epoch : 10/20, Train Loss : 0.7471251636743546, Train Metric ( Accuracy) : 0.7269636392593384, Val Metric (accuracy) : 0.7148000001907349
# Epoch : 11/20, Train Loss : 0.7465107413353743, Train Metric ( Accuracy) : 0.727436363697052, Val Metric (accuracy) : 0.7149999737739563
# Epoch : 12/20, Train Loss : 0.7455396116883667, Train Metric ( Accuracy) : 0.7280545234680176, Val Metric (accuracy) : 0.7161999940872192
# Epoch : 13/20, Train Loss : 0.7451659562411131, Train Metric ( Accuracy) : 0.7282000184059143, Val Metric (accuracy) : 0.7166000008583069
# Epoch : 14/20, Train Loss : 0.7440075946074945, Train Metric ( Accuracy) : 0.7287999987602234, Val Metric (accuracy) : 0.7161999940872192
# Epoch : 15/20, Train Loss : 0.7429623747313464, Train Metric ( Accuracy) : 0.7291272878646851, Val Metric (accuracy) : 0.7167999744415283
# Epoch : 16/20, Train Loss : 0.7422477696780805, Train Metric ( Accuracy) : 0.729418158531189, Val Metric (accuracy) : 0.7161999940872192
# Epoch : 17/20, Train Loss : 0.7414779171899513, Train Metric ( Accuracy) : 0.7300545573234558, Val Metric (accuracy) : 0.7170000076293945
# Epoch : 18/20, Train Loss : 0.740402559991236, Train Metric ( Accuracy) : 0.7305636405944824, Val Metric (accuracy) : 0.7170000076293945
# Epoch : 19/20, Train Loss : 0.739742722776201, Train Metric ( Accuracy) : 0.7310909032821655, Val Metric (accuracy) : 0.7175999879837036
# Epoch : 20/20, Train Loss : 0.7389918896887038, Train Metric ( Accuracy) : 0.7314181923866272, Val Metric (accuracy) : 0.7182000279426575
# Epoch : 1/20, Train Loss : 0.7382654757411392, Train Metric ( Accuracy) : 0.7316181659698486, Val Metric (accuracy) : 0.718999981880188
# Epoch : 2/20, Train Loss : 0.7372867106287567, Train Metric ( Accuracy) : 0.7320727109909058, Val Metric (accuracy) : 0.7192000150680542
# Epoch : 3/20, Train Loss : 0.7368531652070858, Train Metric ( Accuracy) : 0.7325817942619324, Val Metric (accuracy) : 0.7192000150680542
# Epoch : 4/20, Train Loss : 0.7357662408440201, Train Metric ( Accuracy) : 0.7328909039497375, Val Metric (accuracy) : 0.7200000286102295
# Epoch : 5/20, Train Loss : 0.7349911845392652, Train Metric ( Accuracy) : 0.7334181666374207, Val Metric (accuracy) : 0.7206000089645386
# Epoch : 6/20, Train Loss : 0.7339810756621538, Train Metric ( Accuracy) : 0.7335636615753174, Val Metric (accuracy) : 0.7202000021934509
# Epoch : 7/20, Train Loss : 0.7336533351076974, Train Metric ( Accuracy) : 0.734218180179596, Val Metric (accuracy) : 0.7211999893188477
# Epoch : 8/20, Train Loss : 0.7324682358238432, Train Metric ( Accuracy) : 0.7344181537628174, Val Metric (accuracy) : 0.7215999960899353
# ...
# Epoch : 14/20, Train Loss : 2.2624207536379495, Train Metric ( Accuracy) : 0.21941818296909332, Val Metric (accuracy) : 0.2176000028848648
# Epoch : 15/20, Train Loss : 2.262242028006801, Train Metric ( Accuracy) : 0.21985454857349396, Val Metric (accuracy) : 0.2184000015258789
# Epoch : 16/20, Train Loss : 2.2619857169963695, Train Metric ( Accuracy) : 0.22021818161010742, Val Metric (accuracy) : 0.21860000491142273
# Epoch : 17/20, Train Loss : 2.2618278993500605, Train Metric ( Accuracy) : 0.22059999406337738, Val Metric (accuracy) : 0.21940000355243683
# Epoch : 18/20, Train Loss : 2.261527759057504, Train Metric ( Accuracy) : 0.22118182480335236, Val Metric (accuracy) : 0.22020000219345093
# Epoch : 19/20, Train Loss : 2.2613723366348832, Train Metric ( Accuracy) : 0.22203636169433594, Val Metric (accuracy) : 0.22059999406337738
# Epoch : 20/20, Train Loss : 2.2611100408766003, Train Metric ( Accuracy) : 0.22256363928318024, Val Metric (accuracy) : 0.22100000083446503
# Epoch : 1/20, Train Loss : 2.2609264431176364, Train Metric ( Accuracy) : 0.22305454313755035, Val Metric (accuracy) : 0.22220000624656677
# Epoch : 2/20, Train Loss : 2.2606650281835488, Train Metric ( Accuracy) : 0.22352726757526398, Val Metric (accuracy) : 0.2231999933719635
# Epoch : 3/20, Train Loss : 2.2604423937974154, Train Metric ( Accuracy) : 0.22419999539852142, Val Metric (accuracy) : 0.22380000352859497
# Epoch : 4/20, Train Loss : 2.2601951515233076, Train Metric ( Accuracy) : 0.22469091415405273, Val Metric (accuracy) : 0.22419999539852142
# Epoch : 5/20, Train Loss : 2.2600492106543646, Train Metric ( Accuracy) : 0.22512727975845337, Val Metric (accuracy) : 0.22460000216960907
# Epoch : 6/20, Train Loss : 2.259791915063505, Train Metric ( Accuracy) : 0.2258727252483368, Val Metric (accuracy) : 0.22519999742507935
# Epoch : 7/20, Train Loss : 2.25959661492595, Train Metric ( Accuracy) : 0.22645454108715057, Val Metric (accuracy) : 0.22699999809265137
# Epoch : 8/20, Train Loss : 2.2594142379584135, Train Metric ( Accuracy) : 0.22698181867599487, Val Metric (accuracy) : 0.22759999334812164
# Epoch : 9/20, Train Loss : 2.2591542535358005, Train Metric ( Accuracy) : 0.22759999334812164, Val Metric (accuracy) : 0.22759999334812164
# Epoch : 10/20, Train Loss : 2.2589278375660933, Train Metric ( Accuracy) : 0.22816362977027893, Val Metric (accuracy) : 0.22779999673366547
# Epoch : 11/20, Train Loss : 2.2587366302808127, Train Metric ( Accuracy) : 0.22890909016132355, Val Metric (accuracy) : 0.22859999537467957
# Epoch : 12/20, Train Loss : 2.258454943144763, Train Metric ( Accuracy) : 0.2295636385679245, Val Metric (accuracy) : 0.22939999401569366
# Epoch : 13/20, Train Loss : 2.2582905645723694, Train Metric ( Accuracy) : 0.23005454242229462, Val Metric (accuracy) : 0.23119999468326569
# Epoch : 14/20, Train Loss : 2.258044743979419, Train Metric ( Accuracy) : 0.23072727024555206, Val Metric (accuracy) : 0.2313999980688095
# Epoch : 15/20, Train Loss : 2.257838865121206, Train Metric ( Accuracy) : 0.23125454783439636, Val Metric (accuracy) : 0.2321999967098236
# Epoch : 16/20, Train Loss : 2.2575909583656877, Train Metric ( Accuracy) : 0.23185454308986664, Val Metric (accuracy) : 0.23199999332427979
# Epoch : 17/20, Train Loss : 2.257365630732642, Train Metric ( Accuracy) : 0.2322363704442978, Val Metric (accuracy) : 0.23199999332427979
# Epoch : 18/20, Train Loss : 2.2571177592983953, Train Metric ( Accuracy) : 0.23267272114753723, Val Metric (accuracy) : 0.2329999953508377
# Epoch : 19/20, Train Loss : 2.2568707444049694, Train Metric ( Accuracy) : 0.23312726616859436, Val Metric (accuracy) : 0.23340000212192535
# Epoch : 20/20, Train Loss : 2.2566747157662004, Train Metric ( Accuracy) : 0.23369090259075165, Val Metric (accuracy) : 0.23399999737739563
# Epoch : 1/20, Train Loss : 2.256497449345059, Train Metric ( Accuracy) : 0.23423635959625244, Val Metric (accuracy) : 0.23420000076293945
# Epoch : 2/20, Train Loss : 2.256277444186034, Train Metric ( Accuracy) : 0.2346363663673401, Val Metric (accuracy) : 0.23499999940395355
# Epoch : 3/20, Train Loss : 2.25595752398173, Train Metric ( Accuracy) : 0.23521818220615387, Val Metric (accuracy) : 0.23499999940395355
# Epoch : 4/20, Train Loss : 2.2557869222429066, Train Metric ( Accuracy) : 0.23572726547718048, Val Metric (accuracy) : 0.2354000061750412
# Epoch : 5/20, Train Loss : 2.2555719724407903, Train Metric ( Accuracy) : 0.23641818761825562, Val Metric (accuracy) : 0.2362000048160553
# Epoch : 6/20, Train Loss : 2.2553743057780795, Train Metric ( Accuracy) : 0.23705454170703888, Val Metric (accuracy) : 0.23720000684261322
# Epoch : 7/20, Train Loss : 2.2551172463982194, Train Metric ( Accuracy) : 0.23745454847812653, Val Metric (accuracy) : 0.2370000034570694
# Epoch : 8/20, Train Loss : 2.254894600974189, Train Metric ( Accuracy) : 0.23796363174915314, Val Metric (accuracy) : 0.23800000548362732
# Epoch : 9/20, Train Loss : 2.254668176174164, Train Metric ( Accuracy) : 0.23872727155685425, Val Metric (accuracy) : 0.23800000548362732
# Epoch : 10/20, Train Loss : 2.2544627123408847, Train Metric ( Accuracy) : 0.23925454914569855, Val Metric (accuracy) : 0.23839999735355377
# Epoch : 11/20, Train Loss : 2.254200001557668, Train Metric ( Accuracy) : 0.23985454440116882, Val Metric (accuracy) : 0.2386000007390976
# Epoch : 12/20, Train Loss : 2.2540512173264116, Train Metric ( Accuracy) : 0.24038182199001312, Val Metric (accuracy) : 0.23880000412464142
# Exception in thread Thread-3355 (_pin_memory_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# [W 2026-01-27 18:18:46,445] Trial 3 failed with parameters: {'learning_rate': 1.7073967431528103e-05, 'n_hidden': 263} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/ateeksh/mlrepos/mllibraries/lib/python3.12/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_49782/445158313.py", line 17, in objective
#     history = train_eval(model , train_loader , xentropy , optimizer ,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_49782/316987263.py", line 28, in train_eval
#     for x_batch , y_batch in train_loader:
#   File "/home/ateeksh/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/dataloader.py", line 732, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/home/ateeksh/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/dataloader.py", line 1482, in _next_data
#     idx, data = self._get_data()
#                 ^^^^^^^^^^^^^^^^
#   File "/home/ateeksh/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/dataloader.py", line 1434, in _get_data
#     success, data = self._try_get_data()
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/home/ateeksh/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/dataloader.py", line 1275, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/queue.py", line 180, in get
#     self.not_empty.wait(remaining)
#   File "/usr/lib/python3.12/threading.py", line 359, in wait
#     gotit = waiter.acquire(True, timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1010, in run
# [W 2026-01-27 18:18:46,459] Trial 3 failed with value None.
#     self._target(*self._args, **self._kwargs)
#   File "/home/ateeksh/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/_utils/pin_memory.py", line 52, in _pin_memory_loop
#     do_one_step()
#   File "/home/ateeksh/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/_utils/pin_memory.py", line 28, in do_one_step
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ateeksh/mlrepos/mllibraries/lib/python3.12/site-packages/torch/multiprocessing/reductions.py", line 541, in rebuild_storage_fd
#     fd = df.detach()
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 519, in Client
#     c = SocketClient(address)
#         ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/multiprocessing/connection.py", line 647, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 4
#       2 sampler = optuna.samplers.TPESampler(seed = 42)
#       3 study = optuna.create_study(direction="maximize" , sampler=sampler)
# ----> 4 study.optimize(objective , n_trials=5)
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# Cell In[37], line 17, in objective(trial)
#      14 best_val_score = 0.0
#      16 for epoch in range(n_epoch):
# ---> 17     history = train_eval(model , train_loader , xentropy , optimizer ,
#      18                          valid_loader , accuracy_metric , n_epoch)
#      20     val_score = max(history['val_metric(accuracy)'])
#      22     if val_score > best_val_score:
#
# Cell In[36], line 28, in train_eval(model, train_loader, criterion, optimizer, val_loader, metric, n_epoch)
#      26 metric.reset()
#      27 total_loss = 0
# ---> 28 for x_batch , y_batch in train_loader:
#      29     #data
#      30     x_batch , y_batch = x_batch.to(device) , y_batch.to(device)
#      32     #forward
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1482, in _MultiProcessingDataLoaderIter._next_data(self)
#    1479     return self._process_data(data, worker_id)
#    1481 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1482 idx, data = self._get_data()
#    1483 self._tasks_outstanding -= 1
#    1484 if self._dataset_kind == _DatasetKind.Iterable:
#    1485     # Check for _IterableDatasetStopIteration
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1434, in _MultiProcessingDataLoaderIter._get_data(self)
#    1432 elif self._pin_memory:
#    1433     while self._pin_memory_thread.is_alive():
# -> 1434         success, data = self._try_get_data()
#    1435         if success:
#    1436             return data
#
# File ~/mlrepos/mllibraries/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1275, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1262 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1263     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1264     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1272     # Returns a 2-tuple:
#    1273     #   (bool: whether successfully get data, any: data if successful else None)
#    1274     try:
# -> 1275         data = self._data_queue.get(timeout=timeout)
#    1276         return (True, data)
#    1277     except Exception as e:
#    1278         # At timeout and error, we manually check whether any worker has
#    1279         # failed. Note that this is the only mechanism for Windows to detect
#    1280         # worker failures.
#
# File /usr/lib/python3.12/queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File /usr/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
